# %% [markdown]
# # Code that got data into csv

# %%
# import the function to make a dictionary given the scp number
from DataAnalysisPlan import get_dict, clean_text, get_sentiment

# %%
import pandas as pd

# %%
def scp_num(num):
    '''changes number to be readible by the scp wiki html
    Args:
        num (int or str): number
    Returns:
        n (str): number in format readible by scp wiki html (so 45 becomes 045)
    
    '''
    n = "000" + str(num)
    while len(n) > 4:
        n = n.replace("0", "", 1)
    if n[0] == "0":
        n = n.replace("0", "", 1)
    return(n)

# %%
# create dictionary for every possible scp, and add to dataframe
scp_df = pd.DataFrame()

# create list of all scp numbers
# the first 99 numbers need to be changed to have 0 or 00 in front
num_list = []
for i in range(1, 100):
    num_list.append(scp_num(i))
num_list = num_list + (list(range(100, 8000)))

# loop through all the numbers, add to dataframe only if it was able to get the text
for i in num_list:
    try:
        scp_dict = get_dict(i)
        if scp_dict["Text"] != '':
            scp_df = scp_df.append(scp_dict, ignore_index=True)
    except: 
        pass
scp_df.head()
# Out:
# C:\Users\angel\Documents\GitHub\SecureContainProtect\DataAnalysisPlan.py:105: GuessedAtParserWarning:
#
# No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 105 of the file C:\Users\angel\Documents\GitHub\SecureContainProtect\DataAnalysisPlan.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#   Number   Class  Pos Ratings  Pos Rating Rate  D-Class  \
# 0    002  Euclid       1830.0         0.831063      0.0
# 1    003  Euclid        823.0         0.780095      0.0
# 2    004  Euclid       1151.0         0.860883      0.0
# 3    005    Safe        709.0         0.559590      0.0
# 4    006    Safe        686.0         0.566007      0.0
#
#                                                 Tags  \
# 0  [alive, euclid, featured, scp, structure, tran...
# 1  [alive, biological, computer, director-moose, ...
# 2  [euclid, mind-affecting, portal, scp, spacetim...
# 3                              [adaptive, safe, scp]
# 4  [liquid, location, medical, rewrite, safe, scp...
#
#                                                 Text Sub-Objects  Word Count  \
# 0  Item #: SCP-002\nObject Class: Euclid\nSpecial...        None       857.0
# 1  Item #: SCP-003\nObject Class: Euclid\nSpecial...      [1, 2]      1789.0
# 2  Item #: SCP-004\nObject Class: Euclid\nSpecial...   [1, 2, 7]      1452.0
# 3  Item #: SCP-005\nObject Class: Safe\nSpecial C...        None       373.0
# 4  Item #: SCP-006\nObject Class: Safe\nSpecial C...        None       491.0
#
#   Sentiment
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
scp_df.to_csv("all_scps.csv")

# %% [markdown]
# # Code in CSV- Analyze it

# %%
df = pd.read_csv("all_scps.csv")
# drop na
df = df.dropna(subset = ["Class"])

# %%
df["Class"].unique()
# Out:
# array(['Euclid', 'Safe', 'Keter', 'Anomalous Human',
#        'None (see description)', 'Safe-prodest Euclid-impetus',
#        'Safe Euclid Safe', 'Euclid (see below)', 'Anomalous Safe',
#        'Euclid (See Addendum 109-1)', 'Safe Euclid, see Incident 174-A',
#        'Safe Thaumiel',
#        'Safe (Euclid class considered after incident 185-1. See document 185-1 for details.)',
#        'Euclid/Keter', 'Plant', 'Euclid Safe', 'Safe Euclid',
#        'Primary object classification: Safe, secondary object classification: Safe/Euclid/Keter',
#        'Euclid (With proper counseling, SCP-347 may be considered safe eventually)',
#        'Neutralized', 'Thaumiel', nan, 'Euclid (Potentially Keter)',
#        'Safe* (see containment procedures)', 'Euclid/Potential Keter',
#        'Safe Anomalous Euclid', 'Euclid Safe Neutralized',
#        'Safe Euclid (Class updated after Event 544-423245 by order of O5-█)',
#        'Archon', 'Anomalous Euclid Keter',
#        '(Keter) Due to a review of current documentation as of January 5, 2009, this SCP has been reclassified as Euclid.',
#        'Scarf', 'Euclid (Keter classification under review)',
#        'Safe-impetus', 'Safe Euclid.', 'Euclid-flecto', 'Safe Keter',
#        'Neutralized (Formerly Keter)', 'Euclid Keter',
#        'Euclid (Reclassification to Safe pending confirmation from Foundation Intelligence that [REDACTED])',
#        'Neutralized (formerly Safe)', 'Safe Keter Safe',
#        'Euclid (Request for Keter classification under review, 20██/██/██)',
#        'Keter, containment pending.', 'Neutralized (Previously Keter)',
#        'Safe Neutralized', 'Euclid-alterier', 'Anomalous Euclid',
#        'Euclid-nuntii', 'Safe (formerly Euclid)',
#        'Euclid (formerly Safe, see Incident Reports)', 'Euclid-exsequi',
#        'Safe (Possible Euclid, awaiting further testing)',
#        'Euclid, pending reclassification to Safe reclassification denied, see Addendum 985-003',
#        'Keter Safe', 'Safe Euclid (see Addendum #1026-1)', 'Instrument',
#        'Euclid-alterius', 'Safe Euclid Keter', 'Keter-alterius',
#        'Neutralised (formerly Safe)', 'Safe-nuntii', 'Neutralized Euclid',
#        'Safe-exsequi', 'Anomalous Phenomenon', 'Safe-doctrina',
#        'Anomalous Location', 'Safe Decommissioned Euclid',
#        'Euclid Neutralized',
#        'Neutralized // Phenomenon (see Addendum 1422-3)',
#        'Euclid; Previously Safe.', 'Safe Neutralized Euclid',
#        'Euclid-numen', 'Anomalous Organism',
#        'Neutralized; Previously Safe.',
#        'Extranormal Keter Neutralized Keter',
#        'Safe Euclid (See Incident Report 1652-1)', 'Safe-praedico',
#        'Euclid Keter Neutralized', 'Neutralized (Safe)',
#        'Safe (Change to Neutralized under O5 review)',
#        'Safe Euclid, see Incident Log 1820-7.3',
#        'Anomalous Organism (sapient)',
#        'Neutralized (formerly Euclid; see Addendum)', 'Safe-reliquia',
#        'Keter (Presumed Neutralized)',
#        'Neutralized (Keter classification revoked on ██/██/20██)',
#        'Zeno (Medium Containment Difficulty/Low Threat)',
#        'Euclid (Undergoing Neutralization)', 'Safe Keter1',
#        'Safe Euclid Keter Euclid', '* Kronecker', 'Multiple',
#        'Safe (pending review following test 2124-09)',
#        'Euclid NEUUtrallized', 'Euclid Keter Thaumiel',
#        'Thaumiel (SCP-2140-1-D is considered Neutralized)',
#        'Keter Neutralized Safe', 'None', 'Keter (formerly Euclid)',
#        'Keter (provisional)', 'Euclid (Pending Containment)',
#        'Neutralized (formerly Euclid)', '[DATA EXPUNGED]',
#        'Keter (previously Euclid)', 'Keter Euclid',
#        'Safe Keter (See Addendum 2460-B)', 'Safe1',
#        'Safe Keter Presumed Neutralized', 'Neutralized Safe',
#        'Euclid (Keter classification pending)',
#        'Neutralized (formerly Keter)', 'Euclid (previously Safe)',
#        'Euclid - Yellow', 'Euclid (formerly Keter)',
#        'Euclid (pending Keter)', 'Safe (pending Euclid)',
#        'Keter Neutralized', 'Keter (Formerly Euclid)',
#        'Keter (Safe classification pending containment)', 'Pending',
#        "Safe There's something going on, seems to keep us from being able to edit this slot. Probably whatever's making you write in the format.",
#        'Keter-provisi Euclid',
#        'Euclid (SCP-2736-1), Keter (SCP-2736-2) Neutralized',
#        'Euclid Thaumiel', 'Humanoid/Mechanical', 'BFF', '[Pending]',
#        'Keter (previously Euclid; upgraded since 01/07/1975)',
#        'Anomalous Entity', 'Euclid (Formerly Safe)',
#        'Safe Euclid (Revision first proposed 11/30/12, confirmed on 2/4/13; see Incident Log 2925-A and Related Documents, and Formal Request for Upgrade)',
#        'Euclid (provisional, pending adoption of containment procedures)',
#        'Keter-potissimi', 'Safe Euclid (Provisional) Safe',
#        'Euclid Pending Keter Reclassification (See Interview 2992-18)',
#        'Uncontained (Unknown)', 'Pending O5 Review',
#        'Euclid Neutralized1', 'Keter Neutralised', 'Euclid1',
#        'Safe (presumed Neutralized)', 'Keter Neutralized Hiemal',
#        'Edifice', 'Extraterrestrial', 'Ectoentropic Online',
#        "Safe or Euclid I guess. Let's go with Euclid since I'm not sure.",
#        'Audiovisual', 'Keter Declassified', 'Safe Keter (see notice)',
#        'Keter Thaumiel', 'Safe Uncontained', 'Archon1', 'Thaumiel1',
#        'Keter Euclid1 Safe2', 'Safe Pending Explained, 5/5/2018',
#        'Extraterrestrial/Crustacean', 'Thaumiel Neutralized',
#        'Keter (Neutralized)', 'Euclid Urgent reclassification required.',
#        'Neutralised', 'Keter1', 'Uncontained', 'Anomalous Uncontained',
#        'Hiemal', 'Keter Neutralized1', 'Pathogen', 'Insectoid/Telepathic',
#        'Euclid (pending)', 'Keter - Uncontained', 'Geographical',
#        'Thaumiel/Uncontained', 'Keter/Uncontained', 'Declassified',
#        'Neutralized (Formerly Euclid)',
#        'Euclid Uncontained/Neutralised Euclid', 'Unclassed', 'Unassigned',
#        'Safe Neutralised', 'Euclid Neutralised', 'Apollyon',
#        'Safe Apollyon', 'Thaumiel Keter', 'Eparch1',
#        'Euclid Neutralized Safe', 'Hera (Hostile/High Utility)',
#        'Thaumiel Hiemal', 'Keter Uncontained (pending) Pending',
#        'Insectoid', 'Safe/Neutralised',
#        'Presumed Neutralized (Formerly Keter)', 'ARCHON', 'Textual',
#        'To be decided', 'Thaumiel Safe', 'Neutralized1',
#        'Safe (Pending Euclid)', 'Safe for Public', 'Artifact',
#        'Keter Safe1', 'Safe Euclid (See Addendum 4408-1)', 'Safe Yesod',
#        'Spiritual', 'Safe (upgrade to Keter under consideration)',
#        'Gödel1', 'Unknown', 'Euclid Uncontained', 'Azathoth Euclid',
#        'Decommissioned', 'Neutralized Euclid1', 'EuclidObject Class: N/A',
#        'Uncontained/Euclid', 'Memetic', 'Humanoid/Parauniversal',
#        'Parauniversal', 'Canine', 'Keter(2)', 'Safe (Uncontained)',
#        'Keter Apollyon', 'the simpsons farting',
#        'Keter… or Thaumiel, depending on perspective.',
#        'Neutralized (Formerly Safe)', 'Keter / Thaumiel',
#        'Humanoid/Artifact', 'Tiamat',
#        'Safe (initially presumed Neutralized)', 'Keter-provisi',
#        'Euclid Explained', 'Thaumiel, you idiots.', 'Phenomenon',
#        'Unnecessary', 'Malchut', 'Euclid-Adviso', 'Archived',
#        'Euclid-doctrina Euclid-prodist1', 'Safe Neutralized Safe',
#        "Da'aS Elyon", 'Safe, hopefully. Or should that be Euclid?',
#        'Apollyon Neutralized', 'Presumed Safe',
#        'Keter-provisi Safe-supernus', 'Gödel-Euclid Gödel-Keter',
#        'Thaumiel Decommissioned', 'Hiemal1',
#        'Decommissioned (previously Euclid)', 'Safe Euclid/Pending',
#        'Euclid Neutralized (see Addendum 5403-4)', 'Euclid-provisi1',
#        'Presumed Neutralized', 'Euclid Formerly Safe', 'Keter Integrated',
#        'Entos1', 'Safe (provisional)', 'Neutralized/Euclid',
#        'Keter [Formerly Thaumiel]', 'Safe6',
#        'Safe Euclid Keter Neutralized', 'Safe Pending', 'Sköll1',
#        'Ticonderoga',
#        "Keter.What's that mean? It sounds like that musical instrument that's a keyboard and guitar. Ba dum dum dunaaaa ♪♪♪ヽ(ˇ∀ˇ )ゞ",
#        'Neutralized, formerly Euclid',
#        'Explained (pending -EX designation)', 'Explained', '[REDACTED]',
#        'Cernunnos1', 'Euclid (formerly Safe)',
#        'Thaumiel (Formerly Explained)', 'PENDING', 'Uncontainable/Tiamat',
#        'Undefined', 'Legally Uncontainable', 'Uncontainable', 'Gevurah1',
#        'Explained, soon to be Declassified (This classification is currently under review. In compliance with the cautionary principle, this anomaly should not be treated as explained, nor should it be declassified, until the review process is complete.)',
#        'Safe (formerly Thaumiel)', 'Cor', 'Thaumiel-Provisi', 'apollyon',
#        'Safe (Pending Ticonderoga)', 'Euclid-Doctrina', 'Radix', 'Joke',
#        'Safe-provisi', 'Safe Neutralized (See Addendum-6309-B)',
#        'Keter, Pending Euclid', 'Non-Anomalous', 'Keter2',
#        'Euclid (Pending Keter reclassification.)',
#        'Safe (Pending Reclassification to Euclid)',
#        'Keter Decommissioned', 'Keter-Dark | Area | Cognitohazard',
#        'Archon1/Neutralized2', 'Safe Euclid Uncontained',
#        'Pending Neutralized', 'Argus', 'Pending [?]', 'Safe (Revised)',
#        'Euclid Argus1', 'Anomalous Pending',
#        'Safe [Reclassification pending]', 'Humanoid/Artefact',
#        'Ticonderoga1', 'Potentially Neutralized [See Incident 6813]',
#        'Safe Presumed Neutralized', 'Neutralised (formerly Euclid)',
#        'Euclid Pending', 'Thaumiel Euclid',
#        'Keter (pending declassification)',
#        'OFFICIAL OBJECT CLASS AWAITING APPROVAL. PROVISIONAL OBJECT CLASS IS: Euclid',
#        'Keter/Flor Galana1', 'Euclid Explained Keter', 'Keter Resolved',
#        'Safe Euclid1',
#        "Keter The stage is set, and even yet the Parents strain to hear; the dancers' feet tap to the beat, it rocks the atmosphere.",
#        'Euclid SERENDIPITYSYZYGY', 'Location', 'Anomalous1',
#        'Safe-Draugr1', '[DATA EXPUNGED]1', 'pending', 'Enochian',
#        'Dependent1'], dtype=object)

# %%
from collections import Counter
import ast

print("There are", len(df["Tags"].unique()), "different tags")
# get common tags
# convert each string to list of tags, add all tags into a list of lists
tags = [ast.literal_eval(i) for i in df["Tags"]]

# flatten list of lists into list of all tags
tags_list = [item for sublist in tags for item in sublist]

# count amount of each tag
count = Counter(tags_list)

# plot most common
# get 20 most common tags
common = count.most_common(20)
print(common)
# unzip tags and their occurances in x and y
x, y = zip(*common)
# plot x and y
plt.bar(x, y)


# ideas: use bag of words to figure out way to put tags/texts into numerical way to compare
# https://vitalflux.com/text-classification-bag-of-words-model-python-sklearn/
# Out:
# There are 5565 different tags
# [('scp', 5608), ('euclid', 2233), ('safe', 1944), ('humanoid', 1434), ('sapient', 1370), ('alive', 1111), ('keter', 959), ('mind-affecting', 834), ('visual', 584), ('animal', 579), ('cognitohazard', 524), ('ectoentropic', 517), ('extradimensional', 501), ('artifact', 487), ('biological', 465), ('location', 439), ('transfiguration', 424), ('building', 418), ('autonomous', 397), ('uncontained', 366)]
# <BarContainer object of 20 artists>

# %% [markdown]
# # Recommendation Algorithmn

# %%
# try out some recommendation stuff: https://www.geeksforgeeks.org/music-recommendation-system-using-machine-learning/?ref=rp
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
# remove columns wont be using
df_rec = df.drop(["Unnamed: 0", "Sentiment", "Text", "Sub-Objects"], axis = 1)
#df_rec = df_rec.head(1000)

df_rec.head()
# Out:
#    Number   Class  Pos Ratings  Pos Rating Rate  D-Class  \
# 0       2  Euclid       1830.0         0.831063      0.0
# 1       3  Euclid        823.0         0.780095      0.0
# 2       4  Euclid       1151.0         0.860883      0.0
# 3       5    Safe        709.0         0.559590      0.0
# 4       6    Safe        686.0         0.566007      0.0
#
#                                                 Tags  Word Count
# 0  ['alive', 'euclid', 'featured', 'scp', 'struct...       857.0
# 1  ['alive', 'biological', 'computer', 'director-...      1789.0
# 2  ['euclid', 'mind-affecting', 'portal', 'scp', ...      1452.0
# 3                        ['adaptive', 'safe', 'scp']       373.0
# 4  ['liquid', 'location', 'medical', 'rewrite', '...       491.0

# %%
# transform tags into words
import ast

tags = [ast.literal_eval(i) for i in df_rec["Tags"]]
for i in range(len(tags)):
    tags[i] = ' '.join([str(elem) for elem in tags[i]])
df_rec["Tags"] = tags
df_rec.head()
# Out:
#    Number   Class  Pos Ratings  Pos Rating Rate  D-Class  \
# 0       2  Euclid       1830.0         0.831063      0.0
# 1       3  Euclid        823.0         0.780095      0.0
# 2       4  Euclid       1151.0         0.860883      0.0
# 3       5    Safe        709.0         0.559590      0.0
# 4       6    Safe        686.0         0.566007      0.0
#
#                                                 Tags  Word Count
# 0  alive euclid featured scp structure transfigur...       857.0
# 1  alive biological computer director-moose eucli...      1789.0
# 2  euclid mind-affecting portal scp spacetime str...      1452.0
# 3                                  adaptive safe scp       373.0
# 4  liquid location medical rewrite safe scp self-...       491.0

# %%
# get similarities between scps
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE

# vectorizer???
scp_vectorizer = CountVectorizer()
scp_vectorizer.fit(df_rec["Tags"])

def get_similarities(scp, data):
  # Getting vector for the input scp
    text_array1 = scp_vectorizer.transform(data[data['Number']==scp]['Tags']).toarray()
    num_array1 = data[data['Number']==scp].select_dtypes(include=np.number).to_numpy()
   
  # We will store similarity for each row of the dataset.
    sim = []
    for idx, row in data.iterrows():
        name = row['Number']
     
    # Getting vector for current song.
        text_array2 = scp_vectorizer.transform(data[data['Number']==name]['Tags']).toarray()
        num_array2 = data[data['Number']==name].select_dtypes(include=np.number).to_numpy()
 
    # Calculating similarities for text as well as numeric features
        text_sim = cosine_similarity(text_array1, text_array2)[0][0]
        num_sim = cosine_similarity(num_array1, num_array2)[0][0]
        sim.append(text_sim + num_sim)
     
    return sim

# %%
def recommend_scp(scp, data):
  # Base case
  if data[data['Number'] == scp].shape[0] == 0:
    print('This SCP is classified or has adult content.')
    return
  data['similarity_factor'] = get_similarities(scp, data)
 
  data.sort_values(by=['similarity_factor'], ascending = [False], inplace=True)
    
  display(data[['Number', "Tags"]][2:7])

# %%
# get recommendations

recommend_scp(96, df_rec)
# Out:
#      Number                                               Tags
# 5         7         alive euclid humanoid miniature planet scp
# 10       12  cognitohazard document euclid mind-affecting m...
# 174     178     clothing euclid humanoid intangible scp visual
# 79       82        alive euclid humanoid predatory sapient scp
# 860     895  artifact cognitohazard euclid hallucination ph...

# %% [markdown]
# # Tree and KNN Classifier Attempts

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
import numpy as np

df = pd.read_csv("all_scps.csv")
# get rid of NA values
df_no_nan = df.dropna(subset = ["Class"])
# drop all classes that aren't Euclid, Safe, Keter, or Thaumiel
classes_bool = (df_no_nan["Class"] == "Euclid") | (df_no_nan["Class"] == "Safe") | (df_no_nan["Class"] == "Keter")| (df_no_nan["Class"] == "Thaumiel")
df_classes = df_no_nan.loc[classes_bool, :]

# get x features
x_feat_list = ["Pos Ratings", "Pos Rating Rate", "D-Class",  "Word Count"]
# extract data from dataframe
x = df_classes.loc[:, x_feat_list].values
y = df_classes.loc[:, "Class"].values

dec_tree_clf = tree.DecisionTreeClassifier(max_depth=3)

# fit data
dec_tree_clf = dec_tree_clf.fit(x, y)

# initialize empty figure (plot_tree sets text size to fill given figure
# if we resize figure afterwards text size remains too small)
plt.figure()
plt.gcf().set_size_inches(15, 10)

# 'plot' decision tree
tree.plot_tree(dec_tree_clf, 
               feature_names=x_feat_list,
               class_names=dec_tree_clf.classes_);

# %%
from sklearn.model_selection import StratifiedKFold

# do a 10-fold cross-validation with max depth=3

n_splits = 10 # 10-fold Cross Validation
max_depth = 5

# initialize k fold
skfold = StratifiedKFold(n_splits=n_splits)

# initialize decision tree
dec_tree_clf = tree.DecisionTreeClassifier(max_depth=max_depth)

# initialize y_pred, stores predictions of y
y_pred = np.empty_like(y)

for train_idx, test_idx in skfold.split(x, y):
    # get training data
    x_train = x[train_idx, :]
    y_train = y[train_idx]
    
    # get test data    
    x_test = x[test_idx, :]
    
    # fit data
    dec_tree_clf = dec_tree_clf.fit(x_train, y_train)
    
    # estimate on test data
    y_pred[test_idx] = dec_tree_clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

conf_mat = confusion_matrix(y_true=y, y_pred=y_pred)

conf_mat_disp = ConfusionMatrixDisplay(conf_mat, display_labels=np.unique(y))

sns.set(font_scale=1.2)
conf_mat_disp.plot()
plt.gcf().set_size_inches(7, 7)
plt.grid(False)
plt.suptitle('max_depth=5 decision tree')

from sklearn.metrics import accuracy_score

accuracy_score(y, y_pred)
# Out:
# 0.43952483801295894

# %%
# do a KNN one

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from copy import copy
from collections import Counter

k = 3 # the k-nearest neighbors

# initialize a knn_classifier
knn_classifier = KNeighborsClassifier(n_neighbors=k)

# construction of kfold object
kfold = StratifiedKFold(n_splits=4) # the k-folds

# allocate an empty array to store predictions in
y_pred = copy(y)

for train_idx, test_idx in kfold.split(x, y):
    # build arrays which correspond to x, y train /test
    x_test = x[test_idx, :]
    x_train = x[train_idx, :]
    y_true_train = y[train_idx]
    
    # fit happens "inplace", we modify the internal state of knn_classifier to remember all the training samples
    knn_classifier.fit(x_train, y_true_train)

    # estimate each class
    y_pred[test_idx] = knn_classifier.predict(x_test)
    
print(accuracy_score(y, y_pred))

conf_mat = confusion_matrix(y_true=y, y_pred=y_pred)

conf_mat_disp = ConfusionMatrixDisplay(conf_mat, display_labels=np.unique(y))
conf_mat_disp.plot()

plt.gcf().set_size_inches(10, 10)

# seaborn turns on grid by default ... looks best without it
plt.grid(False)
# Out:
# 0.4034557235421166

# %% [markdown]
# ## Clustering

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# read in 
df = pd.read_csv("all_scps.csv")

# get x features
x_feat_list = ["Pos Ratings", "Pos Rating Rate", "D-Class",  "Word Count"]
# extract data from dataframe
x = df.loc[:, x_feat_list].values

n_clusters = 2
# kmeans clustering
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(x)
y = kmeans.predict(x)

# plot
sns.scatterplot(data = df, x = "Pos Ratings", y = "Pos Rating Rate", s = 50, hue = y)
plt.gcf().set_size_inches(12, 6)

# %%
# why are there negative rates?
ratings = df["Pos Rating Rate"] <= 0
df_low_ratings = df.loc[ratings, :]
df_low_ratings
# Out:
#       Unnamed: 0  Number     Class  Pos Ratings  Pos Rating Rate  D-Class  \
# 2972        2972    3105     Keter        -21.0        -0.182609      0.0
# 3942        3942    4238    Euclid          0.0         0.000000      0.0
# 5152        5152    6149  apollyon        -10.0        -1.000000      0.0
# 5285        5285    6476     Keter        -14.0        -0.875000      0.0
# 5341        5341    6649      Safe        -12.0        -0.857143      0.0
# 5347        5347    6674     Keter          0.0         0.000000      0.0
# 5407        5407    6846      Safe         -3.0        -0.069767      0.0
# 5495        5495    7045    Euclid        -12.0        -1.000000      0.0
# 5500        5500    7063     Keter        -12.0        -1.000000      0.0
# 5513        5513    7115    Euclid        -13.0        -0.866667      0.0
# 5521        5521    7169      Safe        -11.0        -0.846154      0.0
# 5567        5567    7581     Keter        -11.0        -1.000000      0.0
# 5604        5604    7893      Safe          0.0         0.000000      1.0
#
#                                                    Tags  \
# 2972                                     ['in-rewrite']
# 3942  ['euclid', 'fungus', 'neurological', 'parasiti...
# 5152                                    ['in-deletion']
# 5285                                    ['in-deletion']
# 5341                                    ['in-deletion']
# 5347  ['antimemetic', 'keter', 'knowledge', 'memory-...
# 5407  ['clothing', 'cognitohazard', 'ectoentropic', ...
# 5495                                    ['in-deletion']
# 5500                                    ['in-deletion']
# 5513                                    ['in-deletion']
# 5521                                    ['in-deletion']
# 5567                                    ['in-deletion']
# 5604  ['fungus', 'mind-affecting', 'plant', 'safe', ...
#
#                                                    Text      Sub-Objects  \
# 2972  Item SCP-3105 Object Class Keter Special Conta...              NaN
# 3942  Item SCP-4238 Object Class Euclid Special Cont...       ['1', '2']
# 5152  Item SCP-6149 the all consume amoeba Object Cl...              NaN
# 5285  Item SCP-6476 Object Class Keter Special Conta...       ['1', '3']
# 5341  Item SCP-6649 Object Class Safe Special Contai...              NaN
# 5347  Item SCP-6674 Object Class Keter Special Conta...              NaN
# 5407  Item SCP-6846 Object Class Safe Special Contai...  ['1', '2', '3']
# 5495  Item SCP-7045 Object Class Euclid Special Cont...            ['2']
# 5500  Item SCP-7063 Object Class Keter Special Conta...            ['1']
# 5513  Item SCP-7115 Object Class Euclid Special Cont...       ['1', '2']
# 5521  Item SCP-7169 Object Class Safe Special Contai...              NaN
# 5567  Item SCP-7581 Object Class Keter Special Conta...              NaN
# 5604  Item SCP-7893 Object Class Safe Special Contai...            ['1']
#
#       Word Count  Sentiment
# 2972      1714.0        NaN
# 3942       887.0        NaN
# 5152       291.0        NaN
# 5285       654.0        NaN
# 5341       345.0        NaN
# 5347      2139.0        NaN
# 5407      1401.0        NaN
# 5495       274.0        NaN
# 5500       198.0        NaN
# 5513       804.0        NaN
# 5521       414.0        NaN
# 5567       262.0        NaN
# 5604      1526.0        NaN
